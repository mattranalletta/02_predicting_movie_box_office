# %% [markdown]
# ## Web scraping: Movies
#
# #### Scrape information from boxofficemojo.com to find a list of features for the [top 1000 movies by worldwide box office](https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/).
#
# #### I start out by scraping the first page, which is limited to just the top 200 movies.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/'

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
page = response.text
soup = BeautifulSoup(page)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|012LjolmrML.css,51AZ-Jz5kmL.css,51IB+wfP8qL.css,01evdoiemkL.css,01K+Ps1DeEL.css,01Vctty9pOL.css,314djKvMsUL.css,01ZTetsDh7L.css,11cMnOipjJL.css,01pbA9Lg3yL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR-yL.css,11KLBtpWIAL.css,11nWWh1kQdL.css,11M4XwS6hxL.css,11WgRxUdJRL.css,01dU8+SPlFL.css,11ocrgKoE-L.css,11k89RclloL.css,111-D2qRjiL.css,01QrWuRrZ-L.css,21xBJi4P1GL.css,01M3ZzSySfL.css,01gAR5pB+IL.css,119dKrtBoVL.css,01piEq-AdwL.css,11Z1a0FxSIL.css,01cbS3UK11L.css,21B5OR-vv2L.css,01giMEP+djL.css_.css?AUIClients/AmazonUI&amp;BUIiWFOU#us.not-trident" rel="stylesheet"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/41Q33m0DqCL.css?AUIClients/IMDbMojoSiteAssets" rel="stylesheet"/>
# <script>
# (function(f,h,Q,E){function F(a){v&&v.tag&&v.tag(q(":","aui",a))}function w(a,b){v&&v.count&&v.count("aui:"+a,0===b?0:b||(v.count("aui:"+a)||0)+1)}function m(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function x(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function q(a,b,c,e){b=b&&c?b+a+c:b||c;return e?q(a,b,e):b}function G(a,b,c){try{Object.defineProperty(a,b,{value:c,writable:!1})}catch(e){a[b]=c}return c}function va(a,b){var c=a.length,
# e=c,g=function(){e--||(R.push(b),S||(setTimeout(ca,0),S=!0))};for(g();c--;)da[a[c]]?g():(A[a[c]]=A[a[c]]||[]).push(g)}function wa(a,b,c,e,g){var d=h.createElement(a?"script":"link");x(d,"error",e);g&&x(d,"load",g);a?(d.type="text/javascript",d.async=!0,c&&/AUIClients|images[/]I/.test(b)&&d.setAttribute("crossorigin","anonymous"),d.src=b):(d.rel="stylesheet",d.href=b);h.getElementsByTagName("head")[0].appendChild(d)}function ea(a,b){return function(c,e){function g(){wa(b,c,d,function(b){T?w("resource_unload"):
# d?(d=!1,w("resource_retry"),g()):(w("resource_error"),a.log("Asset failed to load: "+c));b&&b.stopPropagation?b.stopPropagation():f.event&&(f.event.cancelBubble=!0)},e)}if(fa[c])return!1;fa[c]=!0;w("resource_count");var d=!0;return!g()}}function xa(a,b,c){for(var e={name:a,guard:function(c){return b.guardFatal(a,c)},logError:function(c,d,e){b.logError(c,d,e,a)}},g=[],d=0;d<c.length;d++)H.hasOwnProperty(c[d])&&(g[d]=U.hasOwnProperty(c[d])?U[c[d]](H[c[d]],e):H[c[d]]);return g}function B(a,b,c,e,g){return function(d,
# h){function n(){var a=null;e?a=h:"function"===typeof h&&(p.start=C(),a=h.apply(f,xa(d,k,l)),p.end=C());if(b){H[d]=a;a=d;for(da[a]=!0;(A[a]||[]).length;)A[a].shift()();delete A[a]}p.done=!0}var k=g||this;"function"===typeof d&&(h=d,d=E);b&&(d=d?d.replace(ha,""):"__NONAME__",V.hasOwnProperty(d)&&k.error(q(", reregistered by ",q(" by ",d+" already registered",V[d]),k.attribution),d),V[d]=k.attribution);for(var l=[],m=0;m<a.length;m++)l[m]=a[m].replace(ha,"");var p=ia[d||"anon"+ ++ya]={depend:l,registered:C(),
# namespace:k.namespace};c?n():va(l,k.guardFatal(d,n));return{decorate:function(a){U[d]=k.guardFatal(d,a)}}}}function ja(a){return function(){var b=Array.prototype.slice.call(arguments);return{execute:B(b,!1,a,!1,this),register:B(b,!0,a,!1,this)}}}function W(a,b){return function(c,e){e||(e=c,c=E);var g=this.attribution;return function(){y.push(b||{attribution:g,name:c,logLevel:a});var d=e.apply(this,arguments);y.pop();return d}}}function I(a,b){this.load={js:ea(this,!0),css:ea(this)};G(this,"namespace",
# b);G(this,"attribution",a)}function ka(){h.body?t.trigger("a-bodyBegin"):setTimeout(ka,20)}function D(a,b){a.className=X(a,b)+" "+b}function X(a,b){return(" "+a.className+" ").split(" "+b+" ").join(" ").replace(/^ | $/g,"")}function la(a){try{return a()}catch(b){return!1}}function J(){if(K){var a={w:f.innerWidth||n.clientWidth,h:f.innerHeight||n.clientHeight};5<Math.abs(a.w-Y.w)||50<a.h-Y.h?(Y=a,L=4,(a=k.mobile||k.tablet?450<a.w&&a.w>a.h:1250<=a.w)?D(n,"a-ws"):n.className=X(n,"a-ws")):0<L&&(L--,ma=
# setTimeout(J,16))}}function za(a){(K=a===E?!K:!!a)&&J()}function Aa(){return K}function u(a,b){return"sw:"+(b||"")+":"+a+":"}function na(){oa.forEach(function(a){F(a)})}function p(a){oa.push(a)}function pa(a,b,c,e){if(c){b=m(/Chrome/i)&&!m(/Edge/i)&&!m(/OPR/i)&&!a.capabilities.isAmazonApp&&!m(new RegExp(Z+"bwv"+Z+"b"));var g=u(e,"browser"),d=u(e,"prod_mshop"),f=u(e,"beta_mshop");!a.capabilities.isAmazonApp&&c.browser&&b&&(p(g+"supported"),c.browser.action(g,e));!b&&c.browser&&p(g+"unsupported");c.prodMshop&&
# p(d+"unsupported");c.betaMshop&&p(f+"unsupported")}}"use strict";var M=Q.now=Q.now||function(){return+new Q},C=function(a){return a&&a.now?a.now.bind(a):M}(f.performance),N=C(),r=f.AmazonUIPageJS||f.P;if(r&&r.when&&r.register){N=[];for(var l=h.currentScript;l;l=l.parentElement)l.id&&N.push(l.id);return r.log("A copy of P has already been loaded on this page.","FATAL",N.join(" "))}var v=f.ue;F();F("aui_build_date:3.20.6-2020-09-07");var R=[],S=!1;var ca=function(){for(var a=setTimeout(ca,0),b=M();R.length;)if(R.shift()(),
# 50<M()-b)return;clearTimeout(a);S=!1};var da={},A={},fa={},T=!1;x(f,"beforeunload",function(){T=!0;setTimeout(function(){T=!1},1E4)});var ha=/^prv:/,V={},H={},U={},ia={},ya=0,Z=String.fromCharCode(92),y=[],qa=f.onerror;f.onerror=function(a,b,c,e,g){g&&"object"===typeof g||(g=Error(a,b,c),g.columnNumber=e,g.stack=b||c||e?q(Z,g.message,"at "+q(":",b,c,e)):E);var d=y.pop()||{};g.attribution=q(":",g.attribution||d.attribution,d.name);g.logLevel=d.logLevel;g.attribution&&console&&console.log&&console.log([g.logLevel||
# "ERROR",a,"thrown by",g.attribution].join(" "));y=[];qa&&(d=[].slice.call(arguments),d[4]=g,qa.apply(f,d))};I.prototype={logError:function(a,b,c,e){b={message:b,logLevel:c||"ERROR",attribution:q(":",this.attribution,e)};if(f.ueLogError)return f.ueLogError(a||b,a?b:null),!0;console&&console.error&&(console.log(b),console.error(a));return!1},error:function(a,b,c,e){a=Error(q(":",e,a,c));a.attribution=q(":",this.attribution,b);throw a;},guardError:W(),guardFatal:W("FATAL"),guardCurrent:function(a){var b=
# y[y.length-1];return b?W(b.logLevel,b).call(this,a):a},log:function(a,b,c){return this.logError(null,a,b,c)},declare:B([],!0,!0,!0),register:B([],!0),execute:B([]),AUI_BUILD_DATE:"3.20.6-2020-09-07",when:ja(),now:ja(!0),trigger:function(a,b,c){var e=M();this.declare(a,{data:b,pageElapsedTime:e-(f.aPageStart||NaN),triggerTime:e});c&&c.instrument&&O.when("prv:a-logTrigger").execute(function(b){b(a)})},handleTriggers:function(){this.log("handleTriggers deprecated")},attributeErrors:function(a){return new I(a)},
# _namespace:function(a,b){return new I(a,b)}};var t=G(f,"AmazonUIPageJS",new I);var O=t._namespace("PageJS","AmazonUI");O.declare("prv:p-debug",ia);t.declare("p-recorder-events",[]);t.declare("p-recorder-stop",function(){});G(f,"P",t);ka();if(h.addEventListener){var ra;h.addEventListener("DOMContentLoaded",ra=function(){t.trigger("a-domready");h.removeEventListener("DOMContentLoaded",ra,!1)},!1)}var n=h.documentElement,aa=function(){var a=["O","ms","Moz","Webkit"],b=h.createElement("div");return{testGradients:function(){b.style.cssText=
# "background-image:-webkit-gradient(linear,left top,right bottom,from(#1E4),to(white));background-image:-webkit-linear-gradient(left top,#1E4,white);background-image:linear-gradient(left top,#1E4,white);";return~b.style.backgroundImage.indexOf("gradient")},test:function(c){var e=c.charAt(0).toUpperCase()+c.substr(1);c=(a.join(e+" ")+e+" "+c).split(" ");for(e=c.length;e--;)if(""===b.style[c[e]])return!0;return!1},testTransform3d:function(){var a=!1;f.matchMedia&&(a=f.matchMedia("(-webkit-transform-3d)").matches);
# return a}}}();r=n.className;var sa=/(^| )a-mobile( |$)/.test(r),ta=/(^| )a-tablet( |$)/.test(r),k={audio:function(){return!!h.createElement("audio").canPlayType},video:function(){return!!h.createElement("video").canPlayType},canvas:function(){return!!h.createElement("canvas").getContext},svg:function(){return!!h.createElementNS&&!!h.createElementNS("http://www.w3.org/2000/svg","svg").createSVGRect},offline:function(){return navigator.hasOwnProperty&&navigator.hasOwnProperty("onLine")&&navigator.onLine},
# dragDrop:function(){return"draggable"in h.createElement("span")},geolocation:function(){return!!navigator.geolocation},history:function(){return!(!f.history||!f.history.pushState)},webworker:function(){return!!f.Worker},autofocus:function(){return"autofocus"in h.createElement("input")},inputPlaceholder:function(){return"placeholder"in h.createElement("input")},textareaPlaceholder:function(){return"placeholder"in h.createElement("textarea")},localStorage:function(){return"localStorage"in f&&null!==
# f.localStorage},orientation:function(){return"orientation"in f},touch:function(){return"ontouchend"in h},gradients:function(){return aa.testGradients()},hires:function(){var a=f.devicePixelRatio&&1.5<=f.devicePixelRatio||f.matchMedia&&f.matchMedia("(min-resolution:144dpi)").matches;w("hiRes"+(sa?"Mobile":ta?"Tablet":"Desktop"),a?1:0);return a},transform3d:function(){return aa.testTransform3d()},touchScrolling:function(){return m(/Windowshop|android|OS ([5-9]|[1-9][0-9]+)(_[0-9]{1,2})+ like Mac OS X|Chrome|Silk|Firefox|Trident.+?; Touch/i)},
# ios:function(){return m(/OS [1-9][0-9]*(_[0-9]*)+ like Mac OS X/i)&&!m(/trident|Edge/i)},android:function(){return m(/android.([1-9]|[L-Z])/i)&&!m(/trident|Edge/i)},mobile:function(){return sa},tablet:function(){return ta},rtl:function(){return"rtl"===n.dir}};for(l in k)k.hasOwnProperty(l)&&(k[l]=la(k[l]));for(var ba="textShadow textStroke boxShadow borderRadius borderImage opacity transform transition".split(" "),P=0;P<ba.length;P++)k[ba[P]]=la(function(){return aa.test(ba[P])});var K=!0,ma=0,Y=
# {w:0,h:0},L=4;J();x(f,"resize",function(){clearTimeout(ma);L=4;J()});var ua={getItem:function(a){try{return f.localStorage.getItem(a)}catch(b){}},setItem:function(a,b){try{return f.localStorage.setItem(a,b)}catch(c){}}};n.className=X(n,"a-no-js");D(n,"a-js");!m(/OS [1-8](_[0-9]*)+ like Mac OS X/i)||f.navigator.standalone||m(/safari/i)||D(n,"a-ember");r=[];for(l in k)k.hasOwnProperty(l)&&k[l]&&r.push("a-"+l.replace(/([A-Z])/g,function(a){return"-"+a.toLowerCase()}));D(n,r.join(" "));n.setAttribute("data-aui-build-date",
# "3.20.6-2020-09-07");t.register("p-detect",function(){return{capabilities:k,localStorage:k.localStorage&&ua,toggleResponsiveGrid:za,responsiveGridEnabled:Aa}});m(/UCBrowser/i)||k.localStorage&&D(n,ua.getItem("a-font-class"));t.declare("a-event-revised-handling",!1);try{var z=navigator.serviceWorker}catch(a){F("sw:nav_err")}z&&(x(z,"message",function(a){a&&a.data&&w(a.data.k,a.data.v)}),z.controller&&z.controller.postMessage("MSG-RDY"));var oa=[];(function(a){var b=a.reg,c=a.unreg;z&&z.getRegistrations?
# (O.when("A","a-util").execute(function(a,b){pa(a,b,c,"unregister")}),x(f,"load",function(){O.when("A","a-util").execute(function(a,c){pa(a,c,b,"register");na()})})):(b&&(b.browser&&p(u("register","browser")+"unsupported"),b.prodMshop&&p(u("register","prod_mshop")+"unsupported"),b.betaMshop&&p(u("register","beta_mshop")+"unsupported")),c&&(c.browser&&p(u("unregister","browser")+"unsupported"),c.prodMshop&&p(u("unregister","prod_mshop")+"unsupported"),c.betaMshop&&p(u("unregister","beta_mshop")+"unsupported")),
# na())})({reg:{},unreg:{}});t.declare("a-fix-event-off",!1);w("pagejs:pkgExecTime",C()-N)})(window,document,Date);
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/61-6nKPKyWL._RC|11Y+5x+kkTL.js,61xmyjKeOpL.js,212PEt8u8bL.js,11KoZmq92cL.js,51NVUqbpjpL.js,11AHlQhPRjL.js,01Gpt4sPPhL.js,11OREnu1epL.js,11p81T3qWFL.js,21r53SJg7LL.js,0190vxtlzcL.js,51xpo+OFSiL.js,3139553HcbL.js,015c-6CIP9L.js,01ezj5Rkz1L.js,11EemQQsS-L.js,31pOTH2ZMRL.js,01rpauTep4L.js,01iyxuSGj4L.js,013sPJiqDKL.js_.js?AUIClients/AmazonUI');
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/51DTj2MAGcL.js?AUIClients/IMDbMojoSiteAssets');
# </script>
# </head><body class="mojo-page-id-cso a-m-us a-aui_72554-c a-aui_control_group_273125-c a-aui_dropdown_274033-c a-aui_link_rel_noreferrer_noopener_274172-c a-aui_mm_desktop_exp_291916-c a-aui_mm_desktop_launch_291918-c a-aui_mm_desktop_targeted_exp_291928-c a-aui_mm_desktop_targeted_launch_291922-c a-aui_pci_risk_banner_210084-c a-aui_perf_130093-c a-aui_preload_261698-c a-aui_tnr_v2_180836-c a-aui_ux_145937-c" id="body"><div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{}</script><div class="a-section a-spacing-none mojo-navigation mojo-header mojo-flex mojo-flex-h"><div class="a-section mojo-logo"><a class="a-link-normal" href="/?ref_=bo_nb_cso_mojologo"></a></div><div class="a-section a-spacing-none mojo-nav-elements mojo-flex mojo-flex-h mojo-flex-1"><div class="a-section a-spacing-none mojo-search-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-search"><form action="/search">
# <input id="mojo-search-text-input" name="q" placeholder="Search for Titles" required="true" type="search"/>
# <input class="mojo-inline-button" id="mojo-search-button" type="submit" value=""/>
# </form>
# </div></div><div class="a-section a-spacing-none mojo-mobile-options"><span class="a-declarative" data-a-popover='{"closeButton":"false","inlineContent":"\u003cspan class=\"a-size-medium\"&gt;\u003ca href=\"https://pro.imdb.com/?ref_=mojo_nb_cso_pro&amp;amp;rf=mojo_nb_cso_pro\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;IMDbPro\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://www.facebook.com/BoxOfficeMojo/\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Facebook\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://twitter.com/boxofficemojo\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Twitter\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Help\u003c\/div&gt;\u003c\/a&gt;\u003c\/span&gt;"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="mobile-menu-popover-trigger"></span>
# <i class="a-icon a-icon-popover"></i></a></span></div><div class="a-section a-spacing-none mojo-options mojo-flex"><div class="a-popover-preload" id="a-popover-mojoRollover"><a class="a-link-normal mojo-rollover-image" href="https://pro.imdb.com/login/ap?u=%2Flogin%2Flwa&amp;imdbPageAction=signUp&amp;ref_=mojo_nb_cso_rollover&amp;rf=mojo_nb_cso_rollover"><img alt="" src="https://m.media-amazon.com/images/G/01/IMDbPro/images/ProMojoPD20.png"/></a></div><span class="a-declarative" data-a-popover='{"padding":"none","closeButton":"false","dataStrategy":"preload","name":"mojoRollover","width":"500","position":"triggerBottom","height":"200"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="imdb-pro-logo"></span><i class="a-icon a-icon-popover"></i></a></span><span class="mojo-logo-delimiter"></span><a class="a-link-normal mojo-fb-logo" href="https://www.facebook.com/BoxOfficeMojo/" rel="noopener" target="_blank"></a><a class="a-link-normal mojo-tw-logo" href="https://twitter.com/boxofficemojo" rel="noopener" target="_blank"></a></div></div><div class="a-section a-spacing-none mojo-link-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/date/?ref_=bo_nb_cso_tab">Domestic</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/intl/?ref_=bo_nb_cso_tab">International</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/year/world/?ref_=bo_nb_cso_tab">Worldwide</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/calendar/?ref_=bo_nb_cso_tab">Calendar</a><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_tab">All Time</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/showdown/?ref_=bo_nb_cso_tab">Showdowns</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/brand/?ref_=bo_nb_cso_tab">Indices</a></div></div><div class="a-section a-spacing-none mojo-link-bar-secondary mojo-flex mojo-flex-h"><div class="a-section a-spacing-base mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_secondarytab"><h2 class="a-size-medium a-text-normal">Overall</h2></a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/weekend/?ref_=bo_nb_cso_secondarytab">Weekend Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/daily/?ref_=bo_nb_cso_secondarytab">Daily Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/misc/?ref_=bo_nb_cso_secondarytab">Miscellaneous Records</a></div></div><div class="a-section a-spacing-none mojo-link-bar-fade"><span class="a-letter-space"></span></div></div><main>
# <div class="a-section mojo-body aok-relative"><div class="a-section a-spacing-none"><h1 class="mojo-gutter">Top Lifetime Grosses</h1><div class="a-section mojo-gutter-sides"></div><div class="mojo-refiner mojo-override-gutter">
# <div class="mojo-refinement mojo-refinement-dropdown">
# <span class="mojo-dropdown-clear">
# <form action="" autocomplete="off" class="a-spacing-none" method="post"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown" id="area-navSelector" name="area-navSelector" tabindex="-1"><option value="/chart/top_lifetime_gross/">Domestic</option><option selected="" value="/chart/ww_top_lifetime_gross/?area=XWW">Worldwide</option></select><span class="a-button a-button-dropdown" tabindex="-1"><span class="a-button-inner"><span aria-hidden="true" class="a-button-text a-declarative" data-action="a-dropdown-button" role="button" tabindex="0"><span class="a-dropdown-prompt"></span></span><i class="a-icon a-icon-dropdown"></i></span></span></span></form></span>
# </div>
# </div>
# <div class="a-section a-spacing-none mojo-gutter-sides">Data as of Oct 6, 14:49 PDT</div><div class="a-text-center mojo-pagination"><ul class="a-pagination"><li class="a-disabled">←<span class="a-letter-space"></span><span class="a-letter-space"></span>Previous page</li><li class="a-selected mojo-pagination-button-center"><a href="#">1-200 of 1,000</a></li><li class="a-last"><a href="/chart/ww_top_lifetime_gross/?offset=200">Next page<span class="a-letter-space"></span><span class="a-letter-space"></span>→</a></li></ul></div><style>
# table.a-bordered.mojo-body-table-compact td,
# table.a-bordered.mojo-body-table-compact th {
#     padding: 5px;
# }
# table.mojo-body-table tr.mojo-group-label th {
#     background: linear-gradient(to bottom, #f8f8f8, #eee);
# }
# </style>
# <div class="a-section imdb-scroll-table mojo-gutter-sides" id="table"><div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a></td><td class="a-text-right mojo-field-type-money">$2,797,800,564</td><td class="a-text-right mojo-field-type-money">$858,373,000</td><td class="a-text-right mojo-field-type-percent">30.7%</td><td class="a-text-right mojo-field-type-money">$1,939,427,564</td><td class="a-text-right mojo-field-type-percent">69.3%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2019/?ref_=bo_cso_table_1">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">2</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0499549/?ref_=bo_cso_table_2">Avatar</a></td><td class="a-text-right mojo-field-type-money">$2,790,439,092</td><td class="a-text-right mojo-field-type-money">$760,507,625</td><td class="a-text-right mojo-field-type-percent">27.2%</td><td class="a-text-right mojo-field-type-money">$2,029,931,467</td><td class="a-text-right mojo-field-type-percent">72.8%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2009/?ref_=bo_cso_table_2">2009</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">3</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0120338/?ref_=bo_cso_table_3">Titanic</a></td><td class="a-text-right mojo-field-type-money">$2,195,169,869</td><td class="a-text-right mojo-field-type-money">$659,363,944</td><td class="a-text-right mojo-field-type-percent">30%</td><td class="a-text-right mojo-field-type-money">$1,535,805,925</td><td class="a-text-right mojo-field-type-percent">70%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/1997/?ref_=bo_cso_table_3">1997</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">4</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2488496/?ref_=bo_cso_table_4">Star Wars: Episode VII - The Force Awakens</a></td><td class="a-text-right mojo-field-type-money">$2,068,224,036</td><td class="a-text-right mojo-field-type-money">$936,662,225</td><td class="a-text-right mojo-field-type-percent">45.3%</td><td class="a-text-right mojo-field-type-money">$1,131,561,811</td><td class="a-text-right mojo-field-type-percent">54.7%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2015/?ref_=bo_cso_table_4">2015</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">5</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154756/?ref_=bo_cso_table_5">Avengers: Infinity War</a></td><td class="a-text-right mojo-field-type-money">$2,048,359,754</td><td class="a-text-right mojo-field-type-money">$678,815,482</td><td class="a-text-right mojo-field-type-percent">33.1%</td><td class="a-text-right mojo-field-type-money">$1,369,544,272</td><td class="a-text-right mojo-field-type-percent">66.9%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2018/?ref_=bo_cso_table_5">2018</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">6</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0369610/?ref_=bo_cso_table_6">Jurassic World</a></td><td class="a-text-right mojo-field-type-money">$1,670,401,444</td><td class="a-text-right mojo-field-type-money">$652,270,625</td><td class="a-text-right mojo-field-type-percent">39%</td><td class="a-text-right mojo-field-type-money">$1,018,130,819</td><td class="a-text-right mojo-field-type-percent">61%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2015/ ...
# <div class="a-section a-spacing-none mojo-navigation-frame"><div class="a-section a-spacing-none mojo-navigation mojo-footer"><a class="a-link-normal imdb-pro-logo" href="https://pro.imdb.com/?ref_=mojo_ft_cso_prologo&amp;rf=mojo_ft_cso_prologo"></a><p>
#             Latest Updates:
#             <a class="a-link-normal" href="/news/?ref_=bo_ft_cso_news">News</a> |
#             <a class="a-link-normal" href="/daily/?ref_=bo_ft_cso_daily">Daily</a> |
#             <a class="a-link-normal" href="/weekend/?ref_=bo_ft_cso_weekend">Weekend</a> |
#             <a class="a-link-normal" href="/charts/?ref_=bo_ft_cso_charts">All Time</a> |
#             <a class="a-link-normal" href="/intl/?ref_=bo_ft_cso_intl">International</a> |
#             <a class="a-link-normal" href="/showdown/?ref_=bo_ft_cso_showdown">Showdowns</a></p><p class="mojo-help-row"><a class="a-link-normal" href="https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help" rel="noopener" target="_blank">Help</a></p><p>
#             BoxOfficeMojo.com by IMDbPro - an
#             <a class="a-link-normal" href="http://www.imdb.com/" rel="noopener" target="_blank">IMDb</a>
#             company.
#         </p><p>
#             © IMDb.com, Inc. or its affiliates. All rights reserved.
#             Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates.
#             <a class="a-link-normal" href="/conditions/?ref_=bo_ft_cso_conditions">Conditions of Use</a>
#              and
#              <a class="a-link-normal" href="/privacy/?ref_=bo_ft_cso_privacy">Privacy Policy</a>
#             under which this service is provided to you.
#         </p></div></div></div></body></html>>

# %%
table = soup.find('table')
table
# Out:
# <table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a></td><td class="a-text-right mojo-field-type-money">$2,797,800,564</td><td class="a-text-right mojo-field-type-money">$858,373,000</td><td class="a-text-right mojo-field-type-percent">30.7%</td><td class="a-text-right mojo-field-type-money">$1,939,427,564</td><td class="a-text-right mojo-field-type-percent">69.3%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2019/?ref_=bo_cso_table_1">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">2</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0499549/?ref_=bo_cso_table_2">Avatar</a></td><td class="a-text-right mojo-field-type-money">$2,790,439,092</td><td class="a-text-right mojo-field-type-money">$760,507,625</td><td class="a-text-right mojo-field-type-percent">27.2%</td><td class="a-text-right mojo-field-type-money">$2,029,931,467</td><td class="a-text-right mojo-field-type-percent">72.8%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2009/?ref_=bo_cso_table_2">2009</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">3</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0120338/?ref_=bo_cso_table_3">Titanic</a></td><td class="a-text-right mojo-field-type-money">$2,195,169,869</td><td class="a-text-right mojo-field-type-money">$659,363,944</td><td class="a-text-right mojo-field-type-percent">30%</td><td class="a-text-right mojo-field-type-money">$1,535,805,925</td><td class="a-text-right mojo-field-type-percent">70%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/1997/?ref_=bo_cso_table_3">1997</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">4</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2488496/?ref_=bo_cso_table_4">Star Wars: Episode VII - The Force Awakens</a></td><td class="a-text-right mojo-field-type-money">$2,068,224,036</td><td class="a-text-right mojo-field-type-money">$936,662,225</td><td class="a-text-right mojo-field-type-percent">45.3%</td><td class="a-text-right mojo-field-type-money">$1,131,561,811</td><td class="a-text-right mojo-field-type-percent">54.7%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2015/?ref_=bo_cso_table_4">2015</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">5</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154756/?ref_=bo_cso_table_5">Avengers: Infinity War</a></td><td class="a-text-right mojo-field-type-money">$2,048,359,754</td><td class="a-text-right mojo-field-type-money">$678,815,482</td><td class="a-text-right mojo-field-type-percent">33.1%</td><td class="a-text-right mojo-field-type-money">$1,369,544,272</td><td class="a-text-right mojo-field-type-percent">66.9%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2018/?ref_=bo_cso_table_5">2018</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">6</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0369610/?ref_=bo_cso_table_6">Jurassic World</a></td><td class="a-text-right mojo-field-type-money">$1,670,401,444</td><td class="a-text-right mojo-field-type-money">$652,270,625</td><td class="a-text-right mojo-field-type-percent">39%</td><td class="a-text-right mojo-field-type-money">$1,018,130,819</td><td class="a-text-right mojo-field-type-percent">61%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2015/ ...

# %%
rows = [row for row in table.find_all('tr')]
rows[1]
# Out:
# <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a></td><td class="a-text-right mojo-field-type-money">$2,797,800,564</td><td class="a-text-right mojo-field-type-money">$858,373,000</td><td class="a-text-right mojo-field-type-percent">30.7%</td><td class="a-text-right mojo-field-type-money">$1,939,427,564</td><td class="a-text-right mojo-field-type-percent">69.3%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2019/?ref_=bo_cso_table_1">2019</a></td></tr>

# %%
rows[1].find_all('td')
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a></td>,
#  <td class="a-text-right mojo-field-type-money">$2,797,800,564</td>,
#  <td class="a-text-right mojo-field-type-money">$858,373,000</td>,
#  <td class="a-text-right mojo-field-type-percent">30.7%</td>,
#  <td class="a-text-right mojo-field-type-money">$1,939,427,564</td>,
#  <td class="a-text-right mojo-field-type-percent">69.3%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2019/?ref_=bo_cso_table_1">2019</a></td>]

# %%
rows[1].find_all('td')[1].find('a')['href']
# Out:
# '/title/tt4154796/?ref_=bo_cso_table_1'

# %%
rows[1].find('a')
# Out:
# <a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a>

# %%
top_movies_test = {}

for row in rows[1:201]:
    items = row.find_all('td')
    link_class = items[1].find('a')
    title = link_class.text
    slug = link_class['href']
    top_movies_test[title] = [slug] + [i.text for i in items]

# %%
import pandas as pd

# %%
worldwide_movies = pd.DataFrame(top_movies_test).T
worldwide_movies.columns = ['url slug', 'ranking', 'title', 'worldwise gross', 'domestic gross', 'domestic %', 'foreign gross', 'foreign %', 'year']
worldwide_movies #double-checking I have all 200 movies from the first page
# Out:
#                                                                            url slug  \
# Avengers: Endgame                             /title/tt4154796/?ref_=bo_cso_table_1
# Avatar                                        /title/tt0499549/?ref_=bo_cso_table_2
# Titanic                                       /title/tt0120338/?ref_=bo_cso_table_3
# Star Wars: Episode VII - The Force Awakens    /title/tt2488496/?ref_=bo_cso_table_4
# Avengers: Infinity War                        /title/tt4154756/?ref_=bo_cso_table_5
# ...                                                                             ...
# The Revenant                                /title/tt1663202/?ref_=bo_cso_table_196
# The Meg                                     /title/tt4779682/?ref_=bo_cso_table_197
# Ralph Breaks the Internet                   /title/tt5848272/?ref_=bo_cso_table_198
# Hotel Transylvania 3: Summer Vacation       /title/tt5220122/?ref_=bo_cso_table_199
# The Boss Baby                               /title/tt3874544/?ref_=bo_cso_table_200
#
#                                            ranking  \
# Avengers: Endgame                                1
# Avatar                                           2
# Titanic                                          3
# Star Wars: Episode VII - The Force Awakens       4
# Avengers: Infinity War                           5
# ...                                            ...
# The Revenant                                   196
# The Meg                                        197
# Ralph Breaks the Internet                      198
# Hotel Transylvania 3: Summer Vacation          199
# The Boss Baby                                  200
#
#                                                                                  title  \
# Avengers: Endgame                                                    Avengers: Endgame
# Avatar                                                                          Avatar
# Titanic                                                                        Titanic
# Star Wars: Episode VII - The Force Awakens  Star Wars: Episode VII - The Force Awakens
# Avengers: Infinity War                                          Avengers: Infinity War
# ...                                                                                ...
# The Revenant                                                              The Revenant
# The Meg                                                                        The Meg
# Ralph Breaks the Internet                                    Ralph Breaks the Internet
# Hotel Transylvania 3: Summer Vacation            Hotel Transylvania 3: Summer Vacation
# The Boss Baby                                                            The Boss Baby
#
#                                            worldwise gross domestic gross  \
# Avengers: Endgame                           $2,797,800,564   $858,373,000
# Avatar                                      $2,790,439,092   $760,507,625
# Titanic                                     $2,195,169,869   $659,363,944
# Star Wars: Episode VII - The Force Awakens  $2,068,224,036   $936,662,225
# Avengers: Infinity War                      $2,048,359,754   $678,815,482
# ...                                                    ...            ...
# The Revenant                                  $532,950,503   $183,637,894
# The Meg                                       $530,259,473   $145,443,742
# Ralph Breaks the Internet                     $529,323,962   $201,091,711
# Hotel Transylvania 3: Summer Vacation         $528,583,774   $167,510,016
# The Boss Baby                                 $527,965,936   $175,003,033
#
#                                            domestic %   foreign gross  \
# Avengers: Endgame                               30.7%  $1,939,427,564
# Avatar                                          27.2%  $2,029,931,467
# Titanic                                           30%  $1,535,805,925
# Star Wars: Episode VII - The Force Awakens      45.3%  $1,131,561,811
# Avengers: Infinity War                          33.1%  $1,369,544,272
# ...                                               ...             ...
# The Revenant                                    34.5%    $349,312,609
# The Meg                                         27.4%    $384,815,731
# Ralph Breaks the Internet                         38%    $328,232,251
# Hotel Transylvania 3: Summer Vacation           31.7%    $361,073,758
# The Boss Baby                                   33.2%    $352,962,903
#
#                                            foreign %  year
# Avengers: Endgame                              69.3%  2019
# Avatar                                         72.8%  2009
# Titanic                                          70%  1997
# Star Wars: Episode VII - The Force Awakens     54.7%  2015
# Avengers: Infinity War                         66.9%  2018
# ...                                              ...   ...
# The Revenant                                   65.5%  2015
# The Meg                                        72.6%  2016
# Ralph Breaks the Internet                        62%  2018
# Hotel Transylvania 3: Summer Vacation          68.3%  2018
# The Boss Baby                                  66.8%  2017
#
# [199 rows x 9 columns]

# %% [markdown]
# We now want to do the same process we did for above (but shorter and in a function for movies 201-1000 on the worldwide box office list).

# %%
def gather_movies(url):
    '''Function which repeats the process above but in all one step'''
        
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page)
    
    table = soup.find('table')
    rows = [row for row in table.find_all('tr')]

    top_movies = {}
    
    for row in rows[1:201]:
        items = row.find_all('td')
        link_class = items[1].find('a')
        title = link_class.text
        slug = link_class['href']
        top_movies[title] = [slug] + [i.text for i in items]
        
    return top_movies

#Create 5 separate dictionaries based off the 5 Box Office Mojo web pages of movies with Top Lifetime Grosses

dict1_to_200 = gather_movies('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/')
dict201_to_400 = gather_movies('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?offset=200')
dict401_to_600 = gather_movies('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?offset=400')
dict601_to_800 = gather_movies('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?offset=600')
dict801_to_1000 = gather_movies('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?offset=800')

# %%
#Combine all 5 dictionaries just created and combine them into a single dictionary.

dict1_to_1000 = {**dict1_to_200, **dict201_to_400, **dict401_to_600, **dict601_to_800, **dict801_to_1000}

# %%
#Turn that newly-created giant dictionary into a data frame.

top1000 = pd.DataFrame(dict1_to_1000).T
top1000.columns = ['url_slug', 'ranking', 'title', 'worldwide_gross', 'domestic_gross', 'domestic_%', 'foreign_gross', 'foreign_%', 'year']
top1000
# Out:
#                                                                            url_slug  \
# Avengers: Endgame                             /title/tt4154796/?ref_=bo_cso_table_1
# Avatar                                        /title/tt0499549/?ref_=bo_cso_table_2
# Titanic                                       /title/tt0120338/?ref_=bo_cso_table_3
# Star Wars: Episode VII - The Force Awakens    /title/tt2488496/?ref_=bo_cso_table_4
# Avengers: Infinity War                        /title/tt4154756/?ref_=bo_cso_table_5
# ...                                                                             ...
# Hellboy II: The Golden Army                 /title/tt0411477/?ref_=bo_cso_table_195
# Insidious: The Last Key                     /title/tt5726086/?ref_=bo_cso_table_196
# Unstoppable                                 /title/tt0477080/?ref_=bo_cso_table_198
# Three Men and a Baby                        /title/tt0094137/?ref_=bo_cso_table_199
# Magic Mike                                  /title/tt1915581/?ref_=bo_cso_table_200
#
#                                            ranking  \
# Avengers: Endgame                                1
# Avatar                                           2
# Titanic                                          3
# Star Wars: Episode VII - The Force Awakens       4
# Avengers: Infinity War                           5
# ...                                            ...
# Hellboy II: The Golden Army                  1,010
# Insidious: The Last Key                      1,011
# Unstoppable                                  1,013
# Three Men and a Baby                         1,014
# Magic Mike                                   1,015
#
#                                                                                  title  \
# Avengers: Endgame                                                    Avengers: Endgame
# Avatar                                                                          Avatar
# Titanic                                                                        Titanic
# Star Wars: Episode VII - The Force Awakens  Star Wars: Episode VII - The Force Awakens
# Avengers: Infinity War                                          Avengers: Infinity War
# ...                                                                                ...
# Hellboy II: The Golden Army                                Hellboy II: The Golden Army
# Insidious: The Last Key                                        Insidious: The Last Key
# Unstoppable                                                                Unstoppable
# Three Men and a Baby                                              Three Men and a Baby
# Magic Mike                                                                  Magic Mike
#
#                                            worldwide_gross domestic_gross  \
# Avengers: Endgame                           $2,797,800,564   $858,373,000
# Avatar                                      $2,790,439,092   $760,507,625
# Titanic                                     $2,195,169,869   $659,363,944
# Star Wars: Episode VII - The Force Awakens  $2,068,224,036   $936,662,225
# Avengers: Infinity War                      $2,048,359,754   $678,815,482
# ...                                                    ...            ...
# Hellboy II: The Golden Army                   $168,319,243    $75,986,503
# Insidious: The Last Key                       $167,885,588    $67,745,330
# Unstoppable                                   $167,805,466    $81,562,942
# Three Men and a Baby                          $167,780,960   $167,780,960
# Magic Mike                                    $167,739,368   $113,721,571
#
#                                            domestic_%   foreign_gross  \
# Avengers: Endgame                               30.7%  $1,939,427,564
# Avatar                                          27.2%  $2,029,931,467
# Titanic                                           30%  $1,535,805,925
# Star Wars: Episode VII - The Force Awakens      45.3%  $1,131,561,811
# Avengers: Infinity War                          33.1%  $1,369,544,272
# ...                                               ...             ...
# Hellboy II: The Golden Army                     45.1%     $92,332,740
# Insidious: The Last Key                         40.4%    $100,140,258
# Unstoppable                                     48.6%     $86,242,524
# Three Men and a Baby                             100%              $0
# Magic Mike                                      67.8%     $54,017,797
#
#                                            foreign_%  year
# Avengers: Endgame                              69.3%  2019
# Avatar                                         72.8%  2009
# Titanic                                          70%  1997
# Star Wars: Episode VII - The Force Awakens     54.7%  2015
# Avengers: Infinity War                         66.9%  2018
# ...                                              ...   ...
# Hellboy II: The Golden Army                    54.9%  2008
# Insidious: The Last Key                        59.6%  2018
# Unstoppable                                    51.4%  2010
# Three Men and a Baby                               -  1987
# Magic Mike                                     32.2%  2012
#
# [988 rows x 9 columns]

# %% [markdown]
# #### I'm removing the columns that I don't care about:
# - **title** is already in the index
# - **ranking** is not consistent in the table; some numbers are skipped for seemingly no reason. I can easily just sort the dataframe by **worldwide gross** at any point instead.
# - **foreign gross**, **foreign %**, and **domestic_%** are included in **worldwide gross**, the dependent variable I'm trying to predict.

# %%
top1000 = top1000.drop(['ranking','title','domestic_%','foreign_gross','foreign_%'], axis=1)
top1000
# Out:
#                                                                            url_slug  \
# Avengers: Endgame                             /title/tt4154796/?ref_=bo_cso_table_1
# Avatar                                        /title/tt0499549/?ref_=bo_cso_table_2
# Titanic                                       /title/tt0120338/?ref_=bo_cso_table_3
# Star Wars: Episode VII - The Force Awakens    /title/tt2488496/?ref_=bo_cso_table_4
# Avengers: Infinity War                        /title/tt4154756/?ref_=bo_cso_table_5
# ...                                                                             ...
# Hellboy II: The Golden Army                 /title/tt0411477/?ref_=bo_cso_table_195
# Insidious: The Last Key                     /title/tt5726086/?ref_=bo_cso_table_196
# Unstoppable                                 /title/tt0477080/?ref_=bo_cso_table_198
# Three Men and a Baby                        /title/tt0094137/?ref_=bo_cso_table_199
# Magic Mike                                  /title/tt1915581/?ref_=bo_cso_table_200
#
#                                            worldwide_gross domestic_gross  \
# Avengers: Endgame                           $2,797,800,564   $858,373,000
# Avatar                                      $2,790,439,092   $760,507,625
# Titanic                                     $2,195,169,869   $659,363,944
# Star Wars: Episode VII - The Force Awakens  $2,068,224,036   $936,662,225
# Avengers: Infinity War                      $2,048,359,754   $678,815,482
# ...                                                    ...            ...
# Hellboy II: The Golden Army                   $168,319,243    $75,986,503
# Insidious: The Last Key                       $167,885,588    $67,745,330
# Unstoppable                                   $167,805,466    $81,562,942
# Three Men and a Baby                          $167,780,960   $167,780,960
# Magic Mike                                    $167,739,368   $113,721,571
#
#                                             year
# Avengers: Endgame                           2019
# Avatar                                      2009
# Titanic                                     1997
# Star Wars: Episode VII - The Force Awakens  2015
# Avengers: Infinity War                      2018
# ...                                          ...
# Hellboy II: The Golden Army                 2008
# Insidious: The Last Key                     2018
# Unstoppable                                 2010
# Three Men and a Baby                        1987
# Magic Mike                                  2012
#
# [988 rows x 4 columns]

# %% [markdown]
# #### I now want to add columns from information that exist on the individual pages of each movie and not in the main table:
# - Domestic Distributor
# - Budget
# - Release Date
# - MPAA rating
# - Running Time
# - Genres
# - (and Title, to eventually match with the existing Title in the index)

# %% [markdown]
# #### The following code is playing around with scraping code for Avengers: Endgame to confirm how every object is scraped.

# %%
url_avengers = 'https://www.boxofficemojo.com/title/tt4154796/?ref_=bo_cso_table_1'

#Request HTMl and parse
response_avengers = requests.get(url_avengers)
page_avengers = response_avengers.text
soup = BeautifulSoup(page_avengers)

# %%
#Title
soup.find('title').text.split('-')[0].strip()
# Out:
# 'Avengers: Endgame'

# %%
#Distributor
soup.find(text='Domestic Distributor').findNext().text.split('See')[0]
# Out:
# 'Walt Disney Studios Motion Pictures'

# %%
#Budget
soup.find(text='Budget').findNext(class_='money').text.replace('$','').replace(',','')
# Out:
# '356000000'

# %%
#Release Month
soup.find(text='Earliest Release Date').findNext().text.split()[0]
# Out:
# 'April'

# %%
#MPAA Rating
soup.find(text='MPAA').findNext().text
# Out:
# 'PG-13'

# %%
#Runtime in Minutes
rt = soup.find(text='Running Time').findNext().text.split()
int(rt[0]) * 60 + int(rt[2])
# Out:
# 181

# %%
#Genre
soup.find(text='Genres').findNext().text.split()
# Out:
# ['Action', 'Adventure', 'Drama', 'Sci-Fi']

# %% [markdown]
# #### I'm now going to create a function to find all those elements at once.

# %%
def get_movie_details(slug):
    '''
    Gather additional movie details from the Box Office Mojo individual movie pages.
    Return as a dictionary.
    '''
    
    #Start with the main BOM url that all the subpages lives under
    domain = 'https://www.boxofficemojo.com'
    
    #Create full URL to scrape
    url = domain + slug
    
    #Request HTMl and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page)
    
    column_headers = ['movie_title', 'distributor', 'budget', 'release_month', 'rating', 'runtime','genre']
    
    #Copy formulas I used for Avengers: Endgame above
    
    #Title
    movie_title = soup.find('title').text.split('-')[0].strip()
    #Distributor
    distributor = soup.find(text='Domestic Distributor').findNext().text.split('See')[0]
    #Budget
    budget = soup.find(text='Budget').findNext(class_='money').text.replace('$','').replace(',','')
    #Release Month
    release_month = soup.find(text='Earliest Release Date').findNext().text.split()[0]
    #MPAA rating
    rating = soup.find(text='MPAA').findNext().text
    #Runtime in minutes
    rt = soup.find(text='Running Time').findNext().text.split()
    runtime = int(rt[0]) * 60 + int(rt[2])
    #Genre
    genre = soup.find(text='Genres').findNext().text.split()
    
    #Create dictionary with all elements above
    movie_details = dict(zip(column_headers, [movie_title, distributor, budget, release_month, rating, runtime, genre]))
    
    return movie_details

# %% [markdown]
# #### I now want to use the function above to create a dictionary for the movie page details.
#
# - Some of the movies were throwing AttributeErrors because not all the page data was available. For example, Avengers: Infinity War didn't have a budget listed.
# - Additionally, some of the indexes (that definitely existed) were throwing IndexErrors, so I added some "try/except"s in there so it loops through the whole list without error.

# %%
top1000_info = []

for slug in top1000.url_slug[0:500]:
    try:
        top1000_info.append(get_movie_details(slug))
    except (AttributeError, IndexError):
        pass

# %%
for slug in top1000.url_slug[501:]:
    try:
        top1000_info.append(get_movie_details(slug))
    except (AttributeError, IndexError):
        pass

# %%
top1000_info
# Out:
# [{'movie_title': 'Avengers: Endgame',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '356000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 181,
#   'genre': ['Action', 'Adventure', 'Drama', 'Sci-Fi']},
#  {'movie_title': 'Avatar',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '237000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 162,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Titanic',
#   'distributor': 'Paramount Pictures',
#   'budget': '200000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 194,
#   'genre': ['Drama', 'Romance']},
#  {'movie_title': 'Star Wars: Episode VII',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '245000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 138,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Jurassic World',
#   'distributor': 'Universal Pictures',
#   'budget': '150000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 124,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'The Lion King',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '45000000',
#   'release_month': 'June',
#   'rating': 'G',
#   'runtime': 88,
#   'genre': ['Adventure', 'Animation', 'Drama', 'Family', 'Musical']},
#  {'movie_title': 'The Avengers',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '220000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 143,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Furious 7',
#   'distributor': 'Universal Pictures',
#   'budget': '190000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 137,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'Frozen II',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '150000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 103,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical']},
#  {'movie_title': 'Avengers: Age of Ultron',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '250000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 141,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Star Wars: Episode VIII',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '317000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 152,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Jurassic World: Fallen Kingdom',
#   'distributor': 'Universal Pictures',
#   'budget': '170000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 128,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Frozen',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '150000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 102,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical']},
#  {'movie_title': 'The Fate of the Furious',
#   'distributor': 'Universal Pictures',
#   'budget': '250000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 136,
#   'genre': ['Action', 'Adventure', 'Crime', 'Thriller']},
#  {'movie_title': 'Iron Man 3',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '200000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 130,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Minions',
#   'distributor': 'Universal Pictures',
#   'budget': '74000000',
#   'release_month': 'April',
#   'rating': 'PG',
#   'runtime': 91,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi']},
#  {'movie_title': 'Captain America: Civil War',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '250000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 147,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'The Lord of the Rings: The Return of the King',
#   'distributor': 'New Line Cinema',
#   'budget': '94000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 201,
#   'genre': ['Action', 'Adventure', 'Drama', 'Fantasy']},
#  {'movie_title': 'Spider',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '160000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 129,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Captain Marvel',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '160000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 123,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Transformers: Dark of the Moon',
#   'distributor': 'DreamWorks',
#   'budget': '195000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 154,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Skyfall',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '200000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 143,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'Transformers: Age of Extinction',
#   'distributor': 'Paramount Pictures',
#   'budget': '210000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 165,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'The Dark Knight Rises',
#   'distributor': 'Warner Bros.',
#   'budget': '250000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 164,
#   'genre': ['Action', 'Adventure']},
#  {'movie_title': 'Joker',
#   'distributor': 'Warner Bros.',
#   'budget': '55000000',
#   'release_month': 'October',
#   'rating': 'R',
#   'runtime': 122,
#   'genre': ['Crime', 'Drama', 'Thriller']},
#  {'movie_title': 'Star Wars: Episode IX',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '275000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 141,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Toy Story 4',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '200000000',
#   'release_month': 'June',
#   'rating': 'G',
#   'runtime': 100,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': "Pirates of the Caribbean: Dead Man's Chest",
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '225000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 151,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'Rogue One: A Star Wars Story',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '200000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 133,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Pirates of the Caribbean: On Stranger Tides',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '250000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 137,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'Despicable Me 3',
#   'distributor': 'Universal Pictures',
#   'budget': '80000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 89,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Sci-Fi']},
#  {'movie_title': 'Jurassic Park',
#   'distributor': 'Universal Pictures',
#   'budget': '63000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 127,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Star Wars: Episode I',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '115000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 136,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Forrest Gump',
#   'distributor': 'Paramount Pictures',
#   'budget': '55000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 142,
#   'genre': ['Drama', 'Romance']},
#  {'movie_title': 'Alice in Wonderland',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '200000000',
#   'release_month': 'March',
#   'rating': 'PG',
#   'runtime': 108,
#   'genre': ['Adventure', 'Family', 'Fantasy']},
#  {'movie_title': 'The Dark Knight',
#   'distributor': 'Warner Bros.',
#   'budget': '185000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 152,
#   'genre': ['Action', 'Crime', 'Drama', 'Thriller']},
#  {'movie_title': "Harry Potter and the Sorcerer's Stone",
#   'distributor': 'Warner Bros.',
#   'budget': '125000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 152,
#   'genre': ['Adventure', 'Family', 'Fantasy']},
#  {'movie_title': 'Despicable Me 2',
#   'distributor': 'Universal Pictures',
#   'budget': '76000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 98,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Sci-Fi']},
#  {'movie_title': 'Jumanji: Welcome to the Jungle',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '90000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 119,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Fantasy']},
#  {'movie_title': "Pirates of the Caribbean: At World's End",
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '300000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 169,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'The Lord of the Rings: The Two Towers',
#   'distributor': 'New Line Cinema',
#   'budget': '94000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 179,
#   'genre': ['Action', 'Adventure', 'Drama', 'Fantasy']},
#  {'movie_title': 'Harry Potter and the Order of the Phoenix',
#   'distributor': 'Warner Bros.',
#   'budget': '150000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 138,
#   'genre': ['Action', 'Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'movie_title': 'Harry Potter and the Half',
#   'distributor': 'Warner Bros.',
#   'budget': '250000000',
#   'release_month': 'July',
#   'rating': 'PG',
#   'runtime': 153,
#   'genre': ['Action', 'Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'movie_title': 'Shrek 2',
#   'distributor': 'DreamWorks Distribution',
#   'budget': '150000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 93,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Romance']},
#  {'movie_title': 'Bohemian Rhapsody',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '52000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 134,
#   'genre': ['Biography', 'Drama', 'Music']},
#  {'movie_title': 'Harry Potter and the Goblet of Fire',
#   'distributor': 'Warner Bros.',
#   'budget': '150000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 157,
#   'genre': ['Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'movie_title': 'Spider',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '258000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 139,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'distributor': 'New Line Cinema',
#   'budget': '93000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 178,
#   'genre': ['Action', 'Adventure', 'Drama', 'Fantasy']},
#  {'movie_title': 'Ice Age: Dawn of the Dinosaurs',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '90000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 94,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Spectre',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '245000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 148,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'Spider',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '175000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 133,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Harry Potter and the Chamber of Secrets',
#   'distributor': 'Warner Bros.',
#   'budget': '100000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 161,
#   'genre': ['Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'movie_title': 'Ice Age: Continental Drift',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '95000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 88,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'The Secret Life of Pets',
#   'distributor': 'Universal Pictures',
#   'budget': '75000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 87,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'movie_title': 'Batman v Superman: Dawn of Justice',
#   'distributor': 'Warner Bros.',
#   'budget': '250000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 152,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Star Wars: Episode III',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '113000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 140,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'The Hunger Games: Catching Fire',
#   'distributor': 'Lionsgate',
#   'budget': '130000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 146,
#   'genre': ['Action', 'Adventure', 'Mystery', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Guardians of the Galaxy Vol. 2',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '200000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 136,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'movie_title': 'Inside Out',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '175000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 95,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy']},
#  {'movie_title': 'Venom',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '100000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 112,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Thor: Ragnarok',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '180000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 130,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Inception',
#   'distributor': 'Warner Bros.',
#   'budget': '160000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 148,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Transformers: Revenge of the Fallen',
#   'distributor': 'DreamWorks',
#   'budget': '200000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 149,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'The Twilight Saga: Breaking Dawn',
#   'distributor': 'Lionsgate',
#   'budget': '120000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 115,
#   'genre': ['Adventure', 'Drama', 'Fantasy', 'Romance']},
#  {'movie_title': 'Spider',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '139000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 121,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Wonder Woman',
#   'distributor': 'Warner Bros.',
#   'budget': '149000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 141,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'War']},
#  {'movie_title': 'Independence Day',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '75000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 145,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Fantastic Beasts and Where to Find Them',
#   'distributor': 'Warner Bros.',
#   'budget': '180000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 132,
#   'genre': ['Adventure', 'Family', 'Fantasy']},
#  {'movie_title': 'Shrek the Third',
#   'distributor': 'DreamWorks',
#   'budget': '160000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 93,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Jumanji: The Next Level',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '125000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 123,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Fantasy']},
#  {'movie_title': 'Harry Potter and the Prisoner of Azkaban',
#   'distributor': 'Warner Bros.',
#   'budget': '130000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 142,
#   'genre': ['Adventure', 'Family', 'Fantasy', 'Mystery']},
#  {'movie_title': 'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '230000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 129,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'E.T. the Extra',
#   'distributor': 'Universal Pictures',
#   'budget': '10500000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 115,
#   'genre': ['Family', 'Sci-Fi']},
#  {'movie_title': '2012',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '200000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 158,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Mission: Impossible',
#   'distributor': 'Paramount Pictures',
#   'budget': '178000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 147,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'distributor': 'Paramount Pictures',
#   'budget': '185000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 122,
#   'genre': ['Action', 'Adventure']},
#  {'movie_title': 'Spider',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '200000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 127,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Fast & Furious 6',
#   'distributor': 'Universal Pictures',
#   'budget': '160000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 130,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'Deadpool 2',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '110000000',
#   'release_month': 'May',
#   'rating': 'R',
#   'runtime': 119,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'movie_title': 'Deadpool',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '58000000',
#   'release_month': 'February',
#   'rating': 'R',
#   'runtime': 108,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'movie_title': 'Star Wars: Episode IV',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '11000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 121,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Guardians of the Galaxy',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '170000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 121,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'movie_title': 'The Da Vinci Code',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '125000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 149,
#   'genre': ['Mystery', 'Thriller']},
#  {'movie_title': 'Maleficent',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '180000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 97,
#   'genre': ['Action', 'Adventure', 'Family', 'Fantasy', 'Romance']},
#  {'movie_title': 'The Amazing Spider',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '230000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 136,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'The Hunger Games: Mockingjay',
#   'distributor': 'Lionsgate',
#   'budget': '125000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 123,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Shrek Forever After',
#   'distributor': 'DreamWorks',
#   'budget': '165000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 93,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Romance']},
#  {'movie_title': "Madagascar 3: Europe's Most Wanted",
#   'distributor': 'DreamWorks',
#   'budget': '145000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 95,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'movie_title': 'Suicide Squad',
#   'distributor': 'Warner Bros.',
#   'budget': '175000000',
#   'release_month': 'August',
#   'rating': 'PG-13',
#   'runtime': 123,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'X',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '200000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 132,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '180000000',
#   'release_month': 'December',
#   'rating': 'PG',
#   'runtime': 143,
#   'genre': ['Adventure', 'Family', 'Fantasy']},
#  {'movie_title': 'The Matrix Reloaded',
#   'distributor': 'Warner Bros.',
#   'budget': '150000000',
#   'release_month': 'May',
#   'rating': 'R',
#   'runtime': 138,
#   'genre': ['Action', 'Sci-Fi']},
#  {'movie_title': 'Up',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '175000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 96,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'movie_title': 'Gravity',
#   'distributor': 'Warner Bros.',
#   'budget': '100000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 91,
#   'genre': ['Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Captain America: The Winter Soldier',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '170000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 136,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'The Twilight Saga: Breaking Dawn',
#   'distributor': 'Summit Entertainment',
#   'budget': '110000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 117,
#   'genre': ['Adventure', 'Drama', 'Fantasy', 'Romance', 'Thriller']},
#  {'movie_title': 'The Twilight Saga: New Moon',
#   'distributor': 'Summit Entertainment',
#   'budget': '50000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 130,
#   'genre': ['Adventure', 'Drama', 'Fantasy', 'Romance']},
#  {'movie_title': 'Dawn of the Planet of the Apes',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '170000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 130,
#   'genre': ['Action', 'Adventure', 'Drama', 'Sci-Fi']},
#  {'movie_title': 'Transformers',
#   'distributor': 'DreamWorks',
#   'budget': '150000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 144,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'It',
#   'distributor': 'Warner Bros.',
#   'budget': '35000000',
#   'release_month': 'September',
#   'rating': 'R',
#   'runtime': 135,
#   'genre': ['Horror']},
#  {'movie_title': 'The Twilight Saga: Eclipse',
#   'distributor': 'Summit Entertainment',
#   'budget': '68000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 124,
#   'genre': ['Adventure', 'Drama', 'Fantasy', 'Romance']},
#  {'movie_title': 'Interstellar',
#   'distributor': 'Paramount Pictures',
#   'budget': '165000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 169,
#   'genre': ['Adventure', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Mission: Impossible',
#   'distributor': 'Paramount Pictures',
#   'budget': '145000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 132,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'The Hunger Games',
#   'distributor': 'Lionsgate',
#   'budget': '78000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 142,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Mission: Impossible',
#   'distributor': 'Paramount Pictures',
#   'budget': '150000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 131,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'Doctor Strange',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '165000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 115,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'The Sixth Sense',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '40000000',
#   'release_month': 'August',
#   'rating': 'PG-13',
#   'runtime': 107,
#   'genre': ['Drama', 'Mystery', 'Thriller']},
#  {'movie_title': 'Man of Steel',
#   'distributor': 'Warner Bros.',
#   'budget': '225000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 143,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Ice Age: The Meltdown',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '80000000',
#   'release_month': 'March',
#   'rating': 'PG',
#   'runtime': 91,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Kung Fu Panda 2',
#   'distributor': 'DreamWorks',
#   'budget': '150000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 90,
#   'genre': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy']},
#  {'movie_title': 'The Hunger Games: Mockingjay',
#   'distributor': 'Lionsgate',
#   'budget': '160000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 137,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Big Hero 6',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '165000000',
#   'release_month': 'October',
#   'rating': 'PG',
#   'runtime': 102,
#   'genre': ['Action', 'Adventure', 'Animation', 'Family', 'Sci-Fi']},
#  {'movie_title': 'Fantastic Beasts: The Crimes of Grindelwald',
#   'distributor': 'Warner Bros.',
#   'budget': '200000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 134,
#   'genre': ['Adventure', 'Family', 'Fantasy']},
#  {'movie_title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '140000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 143,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'Star Wars: Episode II',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '115000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 142,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Thor: The Dark World',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '170000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 112,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'Sing',
#   'distributor': 'Universal Pictures',
#   'budget': '75000000',
#   'release_month': 'December',
#   'rating': 'PG',
#   'runtime': 108,
#   'genre': ['Animation', 'Comedy', 'Family', 'Musical']},
#  {'movie_title': 'Kung Fu Panda',
#   'distributor': 'DreamWorks',
#   'budget': '130000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 92,
#   'genre': ['Action', 'Adventure', 'Animation', 'Comedy', 'Family']},
#  {'movie_title': 'The Martian',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '108000000',
#   'release_month': 'September',
#   'rating': 'PG-13',
#   'runtime': 144,
#   'genre': ['Adventure', 'Drama', 'Sci-Fi']},
#  {'movie_title': 'Hancock',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '150000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 92,
#   'genre': ['Action', 'Fantasy']},
#  {'movie_title': 'Fast Five',
#   'distributor': 'Universal Pictures',
#   'budget': '125000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 130,
#   'genre': ['Action', 'Adventure', 'Crime', 'Thriller']},
#  {'movie_title': 'Men in Black 3',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '225000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 106,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'movie_title': 'Iron Man 2',
#   'distributor': 'Paramount Pictures',
#   'budget': '200000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 124,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Ratatouille',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '150000000',
#   'release_month': 'June',
#   'rating': 'G',
#   'runtime': 111,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'How to Train Your Dragon 2',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '145000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 102,
#   'genre': ['Action', 'Adventure', 'Animation', 'Family', 'Fantasy']},
#  {'movie_title': 'Logan',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '97000000',
#   'release_month': 'March',
#   'rating': 'R',
#   'runtime': 137,
#   'genre': ['Action', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'The Lost World: Jurassic Park',
#   'distributor': 'Universal Pictures',
#   'budget': '73000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 129,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Casino Royale',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '150000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 144,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'The Passion of the Christ',
#   'distributor': 'Newmarket Films',
#   'budget': '30000000',
#   'release_month': 'February',
#   'rating': 'R',
#   'runtime': 127,
#   'genre': ['Drama']},
#  {'movie_title': 'Mamma Mia!',
#   'distributor': 'Universal Pictures',
#   'budget': '52000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 108,
#   'genre': ['Comedy', 'Musical', 'Romance']},
#  {'movie_title': 'Life of Pi',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '120000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 127,
#   'genre': ['Adventure', 'Drama', 'Fantasy']},
#  {'movie_title': 'Transformers: The Last Knight',
#   'distributor': 'Paramount Pictures',
#   'budget': '217000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 154,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Madagascar: Escape 2 Africa',
#   'distributor': 'DreamWorks',
#   'budget': '150000000',
#   'release_month': 'October',
#   'rating': 'PG',
#   'runtime': 89,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'movie_title': 'War of the Worlds',
#   'distributor': 'Paramount Pictures',
#   'budget': '132000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 116,
#   'genre': ['Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Tangled',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '260000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 100,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical',
#    'Romance']},
#  {'movie_title': 'Quantum of Solace',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '200000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 106,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'Men in Black',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '90000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 98,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'movie_title': 'The Croods',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '135000000',
#   'release_month': 'March',
#   'rating': 'PG',
#   'runtime': 98,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'The Hangover Part II',
#   'distributor': 'Warner Bros.',
#   'budget': '80000000',
#   'release_month': 'May',
#   'rating': 'R',
#   'runtime': 102,
#   'genre': ['Comedy']},
#  {'movie_title': 'Iron Man',
#   'distributor': 'Paramount Pictures',
#   'budget': '140000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 126,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'I Am Legend',
#   'distributor': 'Warner Bros.',
#   'budget': '150000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 101,
#   'genre': ['Action', 'Adventure', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Ready Player One',
#   'distributor': 'Warner Bros.',
#   'budget': '175000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 140,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Monsters, Inc.',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '115000000',
#   'release_month': 'November',
#   'rating': 'G',
#   'runtime': 92,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Fifty Shades of Grey',
#   'distributor': 'Universal Pictures',
#   'budget': '40000000',
#   'release_month': 'February',
#   'rating': 'R',
#   'runtime': 125,
#   'genre': ['Drama', 'Romance', 'Thriller']},
#  {'movie_title': 'Kong: Skull Island',
#   'distributor': 'Warner Bros.',
#   'budget': '185000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 118,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'The Smurfs',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '110000000',
#   'release_month': 'July',
#   'rating': 'PG',
#   'runtime': 103,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'King Kong',
#   'distributor': 'Universal Pictures',
#   'budget': '207000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 187,
#   'genre': ['Action', 'Adventure', 'Drama', 'Romance']},
#  {'movie_title': 'Cars 2',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '200000000',
#   'release_month': 'June',
#   'rating': 'G',
#   'runtime': 106,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Sport']},
#  {'movie_title': 'Puss in Boots',
#   'distributor': 'DreamWorks',
#   'budget': '130000000',
#   'release_month': 'October',
#   'rating': 'PG',
#   'runtime': 90,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Mystery']},
#  {'movie_title': 'Armageddon',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '140000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 151,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'The Day After Tomorrow',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '125000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 124,
#   'genre': ['Action', 'Adventure', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Star Wars: Episode V',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '18000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 124,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Ted',
#   'distributor': 'Universal Pictures',
#   'budget': '50000000',
#   'release_month': 'June',
#   'rating': 'R',
#   'runtime': 106,
#   'genre': ['Comedy']},
#  {'movie_title': 'American Sniper',
#   'distributor': 'Warner Bros.',
#   'budget': '58800000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 133,
#   'genre': ['Action', 'Biography', 'Drama', 'War']},
#  {'movie_title': 'Mission: Impossible II',
#   'distributor': 'Paramount Pictures',
#   'budget': '125000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 123,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'X',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '178000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 144,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Despicable Me',
#   'distributor': 'Universal Pictures',
#   'budget': '69000000',
#   'release_month': 'July',
#   'rating': 'PG',
#   'runtime': 95,
#   'genre': ['Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Cinderella',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '95000000',
#   'release_month': 'March',
#   'rating': 'PG',
#   'runtime': 105,
#   'genre': ['Drama', 'Family', 'Fantasy', 'Romance']},
#  {'movie_title': 'World War Z',
#   'distributor': 'Paramount Pictures',
#   'budget': '190000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 116,
#   'genre': ['Action', 'Adventure', 'Horror', 'Sci-Fi']},
#  {'movie_title': 'Brave',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '185000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 93,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'The Simpsons Movie',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '75000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 87,
#   'genre': ['Adventure', 'Animation', 'Comedy']},
#  {'movie_title': 'The Revenant',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '135000000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 156,
#   'genre': ['Action', 'Adventure', 'Drama', 'History', 'Western']},
#  {'movie_title': 'The Meg',
#   'distributor': 'Warner Bros.',
#   'budget': '130000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 113,
#   'genre': ['Action', 'Horror', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Ralph Breaks the Internet',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '175000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 112,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Hotel Transylvania 3: Summer Vacation',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '80000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 97,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Dunkirk',
#   'distributor': 'Warner Bros.',
#   'budget': '100000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 106,
#   'genre': ['Action', 'Drama', 'History', 'Thriller', 'War']},
#  {'movie_title': 'Godzilla',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '130000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 139,
#   'genre': ['Action', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Sherlock Holmes',
#   'distributor': 'Warner Bros.',
#   'budget': '90000000',
#   'release_month': 'January',
#   'rating': 'PG-13',
#   'runtime': 128,
#   'genre': ['Action', 'Adventure', 'Mystery']},
#  {'movie_title': 'Meet the Fockers',
#   'distributor': 'Universal Pictures',
#   'budget': '80000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 115,
#   'genre': ['Comedy', 'Romance']},
#  {'movie_title': 'How to Train Your Dragon: The Hidden World',
#   'distributor': 'Universal Pictures',
#   'budget': '129000000',
#   'release_month': 'January',
#   'rating': 'PG',
#   'runtime': 104,
#   'genre': ['Action', 'Adventure', 'Animation', 'Family', 'Fantasy']},
#  {'movie_title': 'Kung Fu Panda 3',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '145000000',
#   'release_month': 'January',
#   'rating': 'PG',
#   'runtime': 95,
#   'genre': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy']},
#  {'movie_title': 'Terminator 2: Judgment Day',
#   'distributor': 'TriStar Pictures',
#   'budget': '102000000',
#   'release_month': 'July',
#   'rating': 'R',
#   'runtime': 137,
#   'genre': ['Action', 'Sci-Fi']},
#  {'movie_title': 'Ant',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '130000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 117,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Sci-Fi']},
#  {'movie_title': "Dr. Seuss' the Grinch",
#   'distributor': 'Universal Pictures',
#   'budget': '75000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 85,
#   'genre': ['Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Rio 2',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '103000000',
#   'release_month': 'March',
#   'rating': 'G',
#   'runtime': 101,
#   'genre': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical']},
#  {'movie_title': 'Troy',
#   'distributor': 'Warner Bros.',
#   'budget': '175000000',
#   'release_month': 'May',
#   'rating': 'R',
#   'runtime': 163,
#   'genre': ['Drama', 'History']},
#  {'movie_title': 'How to Train Your Dragon',
#   'distributor': 'DreamWorks',
#   'budget': '165000000',
#   'release_month': 'March',
#   'rating': 'PG',
#   'runtime': 98,
#   'genre': ['Action', 'Adventure', 'Animation', 'Family', 'Fantasy']},
#  {'movie_title': 'Oz the Great and Powerful',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '215000000',
#   'release_month': 'March',
#   'rating': 'PG',
#   'runtime': 130,
#   'genre': ['Adventure', 'Family', 'Fantasy']},
#  {'movie_title': 'Clash of the Titans',
#   'distributor': 'Warner Bros.',
#   'budget': '125000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 106,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'Maleficent: Mistress of Evil',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '185000000',
#   'release_month': 'October',
#   'rating': 'PG',
#   'runtime': 119,
#   'genre': ['Adventure', 'Family', 'Fantasy']},
#  {'movie_title': 'War for the Planet of the Apes',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '150000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 140,
#   'genre': ['Action', 'Adventure', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Shrek',
#   'distributor': 'DreamWorks Distribution',
#   'budget': '60000000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 90,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Angels & Demons',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '150000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 138,
#   'genre': ['Action', 'Mystery', 'Thriller']},
#  {'movie_title': 'Bruce Almighty',
#   'distributor': 'Universal Pictures',
#   'budget': '81000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 101,
#   'genre': ['Comedy', 'Fantasy']},
#  {'movie_title': 'Rio',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '90000000',
#   'release_month': 'April',
#   'rating': 'PG',
#   'runtime': 96,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Crime', 'Family', 'Musical']},
#  {'movie_title': 'Saving Private Ryan',
#   'distributor': 'DreamWorks Distribution',
#   'budget': '70000000',
#   'release_month': 'July',
#   'rating': 'R',
#   'runtime': 169,
#   'genre': ['Drama', 'War']},
#  {'movie_title': 'Rise of the Planet of the Apes',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '93000000',
#   'release_month': 'August',
#   'rating': 'PG-13',
#   'runtime': 105,
#   'genre': ['Action', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Star Wars: Episode VI',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '32500000',
#   'release_month': 'May',
#   'rating': 'PG',
#   'runtime': 131,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Charlie and the Chocolate Factory',
#   'distributor': 'Warner Bros.',
#   'budget': '150000000',
#   'release_month': 'July',
#   'rating': 'PG',
#   'runtime': 115,
#   'genre': ['Adventure', 'Comedy', 'Family', 'Fantasy', 'Musical']},
#  {'movie_title': 'Hotel Transylvania 2',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '80000000',
#   'release_month': 'September',
#   'rating': 'PG',
#   'runtime': 89,
#   'genre': ['Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Indiana Jones and the Last Crusade',
#   'distributor': 'Paramount Pictures',
#   'budget': '48000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 127,
#   'genre': ['Action', 'Adventure']},
#  {'movie_title': 'San Andreas',
#   'distributor': 'Warner Bros.',
#   'budget': '110000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 114,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'It Chapter Two',
#   'distributor': 'Warner Bros.',
#   'budget': '79000000',
#   'release_month': 'September',
#   'rating': 'R',
#   'runtime': 169,
#   'genre': ['Drama', 'Fantasy', 'Horror']},
#  {'movie_title': 'Wreck',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '165000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 101,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'The Hangover',
#   'distributor': 'Warner Bros.',
#   'budget': '35000000',
#   'release_month': 'June',
#   'rating': 'R',
#   'runtime': 100,
#   'genre': ['Comedy']},
#  {'movie_title': 'The Lego Movie',
#   'distributor': 'Warner Bros.',
#   'budget': '60000000',
#   'release_month': 'February',
#   'rating': 'PG',
#   'runtime': 100,
#   'genre': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy']},
#  {'movie_title': 'Bumblebee',
#   'distributor': 'Paramount Pictures',
#   'budget': '135000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 114,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Star Trek Into Darkness',
#   'distributor': 'Paramount Pictures',
#   'budget': '190000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 132,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'The Matrix',
#   'distributor': 'Warner Bros.',
#   'budget': '63000000',
#   'release_month': 'March',
#   'rating': 'R',
#   'runtime': 136,
#   'genre': ['Action', 'Sci-Fi']},
#  {'movie_title': 'Gladiator',
#   'distributor': 'DreamWorks Distribution',
#   'budget': '103000000',
#   'release_month': 'May',
#   'rating': 'R',
#   'runtime': 155,
#   'genre': ['Action', 'Adventure', 'Drama']},
#  {'movie_title': 'Pretty Woman',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '14000000',
#   'release_month': 'March',
#   'rating': 'R',
#   'runtime': 119,
#   'genre': ['Comedy', 'Romance']},
#  {'movie_title': 'X',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '210000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 104,
#   'genre': ['Action', 'Adventure', 'Sci-Fi']},
#  {'movie_title': 'Lucy',
#   'distributor': 'Universal Pictures',
#   'budget': '40000000',
#   'release_month': 'July',
#   'rating': 'R',
#   'runtime': 89,
#   'genre': ['Action', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Mission: Impossible',
#   'distributor': 'Paramount Pictures',
#   'budget': '80000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 110,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': '300',
#   'distributor': 'Warner Bros.',
#   'budget': '65000000',
#   'release_month': 'March',
#   'rating': 'R',
#   'runtime': 117,
#   'genre': ['Action', 'Drama']},
#  {'movie_title': 'The Last Samurai',
#   'distributor': 'Warner Bros.',
#   'budget': '140000000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 154,
#   'genre': ['Action', 'Drama', 'War']},
#  {'movie_title': "Ocean's Eleven",
#   'distributor': 'Warner Bros.',
#   'budget': '85000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 116,
#   'genre': ['Crime', 'Thriller']},
#  {'movie_title': 'Thor',
#   'distributor': 'Paramount Pictures',
#   'budget': '150000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 115,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'Pearl Harbor',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '140000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 183,
#   'genre': ['Action', 'Drama', 'History', 'Romance', 'War']},
#  {'movie_title': 'Tarzan',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '130000000',
#   'release_month': 'June',
#   'rating': 'G',
#   'runtime': 88,
#   'genre': ['Adventure', 'Animation', 'Family', 'Romance']},
#  {'movie_title': 'La La Land',
# ...
#   'distributor': 'DreamWorks Distribution',
#   'budget': '80000000',
#   'release_month': 'July',
#   'rating': 'R',
#   'runtime': 117,
#   'genre': ['Crime', 'Drama', 'Thriller']},
#  {'movie_title': 'Kill Bill: Vol. 1',
#   'distributor': 'Miramax',
#   'budget': '30000000',
#   'release_month': 'October',
#   'rating': 'R',
#   'runtime': 111,
#   'genre': ['Action', 'Crime', 'Thriller']},
#  {'movie_title': 'The Scorpion King',
#   'distributor': 'Universal Pictures',
#   'budget': '60000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 92,
#   'genre': ['Action', 'Adventure', 'Fantasy']},
#  {'movie_title': 'Sweet Home Alabama',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '30000000',
#   'release_month': 'September',
#   'rating': 'PG-13',
#   'runtime': 108,
#   'genre': ['Comedy', 'Romance']},
#  {'movie_title': "Daddy's Home 2",
#   'distributor': 'Paramount Pictures',
#   'budget': '69000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 100,
#   'genre': ['Comedy']},
#  {'movie_title': 'Deja Vu',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '75000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 126,
#   'genre': ['Action', 'Crime', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Hacksaw Ridge',
#   'distributor': 'Lionsgate',
#   'budget': '40000000',
#   'release_month': 'November',
#   'rating': 'R',
#   'runtime': 139,
#   'genre': ['Biography', 'Drama', 'History', 'War']},
#  {'movie_title': 'The Post',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '50000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 116,
#   'genre': ['Drama', 'Thriller']},
#  {'movie_title': 'The Dictator',
#   'distributor': 'Paramount Pictures',
#   'budget': '65000000',
#   'release_month': 'May',
#   'rating': 'R',
#   'runtime': 83,
#   'genre': ['Comedy']},
#  {'movie_title': 'The League of Extraordinary Gentlemen',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '78000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 110,
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']},
#  {'movie_title': 'Daredevil',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '78000000',
#   'release_month': 'February',
#   'rating': 'PG-13',
#   'runtime': 103,
#   'genre': ['Action', 'Crime']},
#  {'movie_title': 'Abominable',
#   'distributor': 'Universal Pictures',
#   'budget': '75000000',
#   'release_month': 'September',
#   'rating': 'PG',
#   'runtime': 97,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Eagle Eye',
#   'distributor': 'DreamWorks',
#   'budget': '80000000',
#   'release_month': 'September',
#   'rating': 'PG-13',
#   'runtime': 118,
#   'genre': ['Action', 'Mystery', 'Thriller']},
#  {'movie_title': 'Along Came Polly',
#   'distributor': 'Universal Pictures',
#   'budget': '42000000',
#   'release_month': 'January',
#   'rating': 'PG-13',
#   'runtime': 90,
#   'genre': ['Comedy', 'Romance']},
#  {'movie_title': 'Flushed Away',
#   'distributor': 'DreamWorks',
#   'budget': '149000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 85,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Scary Movie 4',
#   'distributor': 'Dimension Films',
#   'budget': '45000000',
#   'release_month': 'April',
#   'rating': 'PG-13',
#   'runtime': 83,
#   'genre': ['Comedy', 'Horror']},
#  {'movie_title': "Dante's Peak",
#   'distributor': 'Universal Pictures',
#   'budget': '116000000',
#   'release_month': 'February',
#   'rating': 'PG-13',
#   'runtime': 108,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'Brokeback Mountain',
#   'distributor': 'Focus Features',
#   'budget': '14000000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 134,
#   'genre': ['Drama', 'Romance']},
#  {'movie_title': 'Patriot Games',
#   'distributor': 'Paramount Pictures',
#   'budget': '45000000',
#   'release_month': 'June',
#   'rating': 'R',
#   'runtime': 117,
#   'genre': ['Action', 'Thriller']},
#  {'movie_title': 'Baywatch',
#   'distributor': 'Paramount Pictures',
#   'budget': '69000000',
#   'release_month': 'May',
#   'rating': 'R',
#   'runtime': 116,
#   'genre': ['Action', 'Comedy', 'Crime']},
#  {'movie_title': 'Double Jeopardy',
#   'distributor': 'Paramount Pictures',
#   'budget': '70000000',
#   'release_month': 'September',
#   'rating': 'R',
#   'runtime': 105,
#   'genre': ['Crime', 'Drama', 'Mystery', 'Thriller']},
#  {'movie_title': 'War Horse',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '66000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 146,
#   'genre': ['Action', 'Adventure', 'Drama', 'History', 'War']},
#  {'movie_title': 'Paranormal Activity 2',
#   'distributor': 'Paramount Pictures',
#   'budget': '3000000',
#   'release_month': 'October',
#   'rating': 'R',
#   'runtime': 91,
#   'genre': ['Horror', 'Mystery']},
#  {'movie_title': 'Alien vs. Predator',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '60000000',
#   'release_month': 'August',
#   'rating': 'PG-13',
#   'runtime': 101,
#   'genre': ['Action', 'Adventure', 'Horror', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'The 40',
#   'distributor': 'Universal Pictures',
#   'budget': '26000000',
#   'release_month': 'August',
#   'rating': 'R',
#   'runtime': 116,
#   'genre': ['Comedy', 'Romance']},
#  {'movie_title': "Lee Daniels' The Butler",
#   'distributor': 'The Weinstein Company',
#   'budget': '30000000',
#   'release_month': 'August',
#   'rating': 'PG-13',
#   'runtime': 132,
#   'genre': ['Biography', 'Drama']},
#  {'movie_title': 'The Haunting',
#   'distributor': 'DreamWorks Distribution',
#   'budget': '80000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 113,
#   'genre': ['Fantasy', 'Horror', 'Mystery', 'Thriller']},
#  {'movie_title': 'The A',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '110000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 117,
#   'genre': ['Action', 'Adventure', 'Thriller']},
#  {'movie_title': 'In the Line of Fire',
#   'distributor': 'Columbia Pictures',
#   'budget': '40000000',
#   'release_month': 'July',
#   'rating': 'R',
#   'runtime': 128,
#   'genre': ['Action', 'Crime', 'Drama', 'Thriller']},
#  {'movie_title': 'Analyze This',
#   'distributor': 'Warner Bros.',
#   'budget': '80000000',
#   'release_month': 'March',
#   'rating': 'R',
#   'runtime': 103,
#   'genre': ['Comedy', 'Crime']},
#  {'movie_title': "The Hitman's Bodyguard",
#   'distributor': 'Lionsgate',
#   'budget': '30000000',
#   'release_month': 'August',
#   'rating': 'R',
#   'runtime': 118,
#   'genre': ['Action', 'Comedy', 'Crime', 'Thriller']},
#  {'movie_title': 'Looper',
#   'distributor': 'TriStar Pictures',
#   'budget': '30000000',
#   'release_month': 'September',
#   'rating': 'R',
#   'runtime': 113,
#   'genre': ['Action', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Dr. Dolittle 2',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '70000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 87,
#   'genre': ['Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'The Italian Job',
#   'distributor': 'Paramount Pictures',
#   'budget': '60000000',
#   'release_month': 'May',
#   'rating': 'PG-13',
#   'runtime': 111,
#   'genre': ['Action', 'Crime', 'Thriller']},
#  {'movie_title': 'The Bucket List',
#   'distributor': 'Warner Bros.',
#   'budget': '45000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 97,
#   'genre': ['Comedy', 'Drama']},
#  {'movie_title': 'Sleeping with the Enemy',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '19000000',
#   'release_month': 'February',
#   'rating': 'R',
#   'runtime': 99,
#   'genre': ['Drama', 'Thriller']},
#  {'movie_title': 'Cowboys & Aliens',
#   'distributor': 'Universal Pictures',
#   'budget': '163000000',
#   'release_month': 'July',
#   'rating': 'PG-13',
#   'runtime': 119,
#   'genre': ['Action', 'Sci-Fi', 'Thriller', 'Western']},
#  {'movie_title': 'The Mule',
#   'distributor': 'Warner Bros.',
#   'budget': '50000000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 116,
#   'genre': ['Crime', 'Drama', 'Thriller']},
#  {'movie_title': 'George of the Jungle',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '55000000',
#   'release_month': 'July',
#   'rating': 'PG',
#   'runtime': 92,
#   'genre': ['Action', 'Adventure', 'Comedy', 'Family', 'Romance']},
#  {'movie_title': 'Evan Almighty',
#   'distributor': 'Universal Pictures',
#   'budget': '175000000',
#   'release_month': 'June',
#   'rating': 'PG',
#   'runtime': 96,
#   'genre': ['Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Identity Thief',
#   'distributor': 'Universal Pictures',
#   'budget': '35000000',
#   'release_month': 'February',
#   'rating': 'R',
#   'runtime': 111,
#   'genre': ['Comedy', 'Crime', 'Drama']},
#  {'movie_title': 'The Nutcracker and the Four Realms',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'budget': '120000000',
#   'release_month': 'October',
#   'rating': 'PG',
#   'runtime': 99,
#   'genre': ['Adventure', 'Family', 'Fantasy']},
#  {'movie_title': "Big Momma's House",
#   'distributor': 'Twentieth Century Fox',
#   'budget': '30000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 99,
#   'genre': ['Action', 'Comedy', 'Crime']},
#  {'movie_title': 'In Time',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '40000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 109,
#   'genre': ['Action', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Amélie',
#   'distributor': 'Miramax',
#   'budget': '10000000',
#   'release_month': 'April',
#   'rating': 'R',
#   'runtime': 122,
#   'genre': ['Comedy', 'Romance']},
#  {'movie_title': 'Anchorman 2: The Legend Continues',
#   'distributor': 'Paramount Pictures',
#   'budget': '50000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 119,
#   'genre': ['Comedy']},
#  {'movie_title': 'Creed',
#   'distributor': 'Warner Bros.',
#   'budget': '35000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 133,
#   'genre': ['Drama', 'Sport']},
#  {'movie_title': 'Gemini Man',
#   'distributor': 'Paramount Pictures',
#   'budget': '138000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 117,
#   'genre': ['Action', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'The Girl on the Train',
#   'distributor': 'Universal Pictures',
#   'budget': '45000000',
#   'release_month': 'October',
#   'rating': 'R',
#   'runtime': 112,
#   'genre': ['Crime', 'Drama', 'Mystery', 'Thriller']},
#  {'movie_title': 'Scream',
#   'distributor': 'Dimension Films',
#   'budget': '14000000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 111,
#   'genre': ['Horror', 'Mystery']},
#  {'movie_title': 'Cold Mountain',
#   'distributor': 'Miramax',
#   'budget': '79000000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 154,
#   'genre': ['Adventure', 'Drama', 'History', 'Romance', 'War']},
#  {'movie_title': 'Black Hawk Down',
#   'distributor': 'Revolution Studios',
#   'budget': '92000000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 144,
#   'genre': ['Drama', 'History', 'War']},
#  {'movie_title': 'The Grand Budapest Hotel',
#   'distributor': 'Fox Searchlight Pictures',
#   'budget': '25000000',
#   'release_month': 'February',
#   'rating': 'R',
#   'runtime': 99,
#   'genre': ['Adventure', 'Comedy', 'Crime']},
#  {'movie_title': 'Cloverfield',
#   'distributor': 'Paramount Pictures',
#   'budget': '25000000',
#   'release_month': 'January',
#   'rating': 'PG-13',
#   'runtime': 85,
#   'genre': ['Action', 'Horror', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Couples Retreat',
#   'distributor': 'Universal Pictures',
#   'budget': '70000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 113,
#   'genre': ['Comedy']},
#  {'movie_title': 'Antz',
#   'distributor': 'DreamWorks Distribution',
#   'budget': '105000000',
#   'release_month': 'October',
#   'rating': 'PG',
#   'runtime': 83,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family']},
#  {'movie_title': 'Blood Diamond',
#   'distributor': 'Warner Bros.',
#   'budget': '100000000',
#   'release_month': 'December',
#   'rating': 'R',
#   'runtime': 143,
#   'genre': ['Adventure', 'Drama', 'Thriller']},
#  {'movie_title': 'Jackass 3D',
#   'distributor': 'Paramount Pictures',
#   'budget': '20000000',
#   'release_month': 'October',
#   'rating': 'R',
#   'runtime': 95,
#   'genre': ['Action', 'Comedy', 'Documentary']},
#  {'movie_title': 'Spies in Disguise',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '100000000',
#   'release_month': 'November',
#   'rating': 'PG',
#   'runtime': 102,
#   'genre': ['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi']},
#  {'movie_title': 'Mr. Deeds',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '50000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 96,
#   'genre': ['Comedy', 'Romance']},
#  {'movie_title': 'Contact',
#   'distributor': 'Warner Bros.',
#   'budget': '90000000',
#   'release_month': 'July',
#   'rating': 'PG',
#   'runtime': 150,
#   'genre': ['Drama', 'Mystery', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Superbad',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '20000000',
#   'release_month': 'August',
#   'rating': 'R',
#   'runtime': 113,
#   'genre': ['Comedy']},
#  {'movie_title': 'The Other Guys',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '100000000',
#   'release_month': 'August',
#   'rating': 'PG-13',
#   'runtime': 107,
#   'genre': ['Action', 'Comedy', 'Crime']},
#  {'movie_title': 'The Specialist',
#   'distributor': 'Warner Bros.',
#   'budget': '45000000',
#   'release_month': 'October',
#   'rating': 'R',
#   'runtime': 110,
#   'genre': ['Action', 'Drama', 'Thriller']},
#  {'movie_title': 'Olympus Has Fallen',
#   'distributor': 'FilmDistrict',
#   'budget': '70000000',
#   'release_month': 'March',
#   'rating': 'R',
#   'runtime': 119,
#   'genre': ['Action', 'Thriller']},
#  {'movie_title': 'Starsky & Hutch',
#   'distributor': 'Warner Bros.',
#   'budget': '60000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 101,
#   'genre': ['Comedy', 'Crime']},
#  {'movie_title': 'Shall We Dance',
#   'distributor': 'Miramax',
#   'budget': '50000000',
#   'release_month': 'October',
#   'rating': 'PG-13',
#   'runtime': 106,
#   'genre': ['Comedy', 'Drama', 'Music', 'Romance']},
#  {'movie_title': 'Stuart Little 2',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '120000000',
#   'release_month': 'July',
#   'rating': 'PG',
#   'runtime': 77,
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']},
#  {'movie_title': 'Zookeeper',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '80000000',
#   'release_month': 'July',
#   'rating': 'PG',
#   'runtime': 102,
#   'genre': ['Comedy', 'Family', 'Fantasy', 'Romance']},
#  {'movie_title': 'Dumb and Dumber To',
#   'distributor': 'Universal Pictures',
#   'budget': '40000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 109,
#   'genre': ['Comedy']},
#  {'movie_title': 'Ghost in the Shell',
#   'distributor': 'Paramount Pictures',
#   'budget': '110000000',
#   'release_month': 'March',
#   'rating': 'PG-13',
#   'runtime': 107,
#   'genre': ['Action', 'Crime', 'Drama', 'Sci-Fi', 'Thriller']},
#  {'movie_title': 'Seven Pounds',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'budget': '55000000',
#   'release_month': 'December',
#   'rating': 'PG-13',
#   'runtime': 123,
#   'genre': ['Drama']},
#  {'movie_title': 'Dodgeball',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '20000000',
#   'release_month': 'June',
#   'rating': 'PG-13',
#   'runtime': 92,
#   'genre': ['Comedy', 'Sport']},
#  {'movie_title': 'Insidious: The Last Key',
#   'distributor': 'Universal Pictures',
#   'budget': '10000000',
#   'release_month': 'January',
#   'rating': 'PG-13',
#   'runtime': 103,
#   'genre': ['Horror', 'Mystery', 'Thriller']},
#  {'movie_title': 'Unstoppable',
#   'distributor': 'Twentieth Century Fox',
#   'budget': '100000000',
#   'release_month': 'November',
#   'rating': 'PG-13',
#   'runtime': 98,
#   'genre': ['Action', 'Thriller']},
#  {'movie_title': 'Magic Mike',
#   'distributor': 'Warner Bros.',
#   'budget': '7000000',
#   'release_month': 'June',
#   'rating': 'R',
#   'runtime': 110,
#   'genre': ['Comedy', 'Drama']}]

# %%
top1000_info_df = pd.DataFrame(top1000_info)
top1000_info_df.set_index('movie_title', inplace=True)

top1000_info_df
# Out:
#                                                  distributor     budget  \
# movie_title
# Avengers: Endgame        Walt Disney Studios Motion Pictures  356000000
# Avatar                                 Twentieth Century Fox  237000000
# Titanic                                   Paramount Pictures  200000000
# Star Wars: Episode VII   Walt Disney Studios Motion Pictures  245000000
# Jurassic World                            Universal Pictures  150000000
# ...                                                      ...        ...
# Seven Pounds               Sony Pictures Entertainment (SPE)   55000000
# Dodgeball                              Twentieth Century Fox   20000000
# Insidious: The Last Key                   Universal Pictures   10000000
# Unstoppable                            Twentieth Century Fox  100000000
# Magic Mike                                      Warner Bros.    7000000
#
#                         release_month rating  runtime  \
# movie_title
# Avengers: Endgame               April  PG-13      181
# Avatar                       December  PG-13      162
# Titanic                      December  PG-13      194
# Star Wars: Episode VII       December  PG-13      138
# Jurassic World                   June  PG-13      124
# ...                               ...    ...      ...
# Seven Pounds                 December  PG-13      123
# Dodgeball                        June  PG-13       92
# Insidious: The Last Key       January  PG-13      103
# Unstoppable                  November  PG-13       98
# Magic Mike                       June      R      110
#
#                                                         genre
# movie_title
# Avengers: Endgame          [Action, Adventure, Drama, Sci-Fi]
# Avatar                   [Action, Adventure, Fantasy, Sci-Fi]
# Titanic                                      [Drama, Romance]
# Star Wars: Episode VII            [Action, Adventure, Sci-Fi]
# Jurassic World                    [Action, Adventure, Sci-Fi]
# ...                                                       ...
# Seven Pounds                                          [Drama]
# Dodgeball                                     [Comedy, Sport]
# Insidious: The Last Key           [Horror, Mystery, Thriller]
# Unstoppable                                [Action, Thriller]
# Magic Mike                                    [Comedy, Drama]
#
# [760 rows x 6 columns]

# %% [markdown]
# #### I now want to merge the two dataframes.

# %%
top1000 = pd.merge(top1000, top1000_info_df, left_index=True, right_index=True)

# %%
top1000.head()
# Out:
#                                                  url_slug worldwide_gross  \
# 10,000 BC         /title/tt0443649/?ref_=bo_cso_table_161    $269,784,201
# 12 Years a Slave   /title/tt2024544/?ref_=bo_cso_table_65    $187,733,202
# 1917              /title/tt8579674/?ref_=bo_cso_table_125    $384,788,959
# 2 Fast 2 Furious   /title/tt0322259/?ref_=bo_cso_table_60    $236,350,661
# 2012               /title/tt1190080/?ref_=bo_cso_table_93    $791,217,826
#
#                  domestic_gross  year                        distributor  \
# 10,000 BC           $94,784,201  2008                       Warner Bros.
# 12 Years a Slave    $56,671,993  2013           Fox Searchlight Pictures
# 1917               $159,227,644  2019                 Universal Pictures
# 2 Fast 2 Furious   $127,154,901  2003                 Universal Pictures
# 2012               $166,112,167  2009  Sony Pictures Entertainment (SPE)
#
#                      budget release_month rating  runtime  \
# 10,000 BC         105000000         March  PG-13      109
# 12 Years a Slave   20000000       October      R      134
# 1917               95000000      December      R      119
# 2 Fast 2 Furious   76000000          June  PG-13      107
# 2012              200000000      November  PG-13      158
#
#                                                          genre
# 10,000 BC         [Action, Adventure, Drama, Fantasy, History]
# 12 Years a Slave                   [Biography, Drama, History]
# 1917                                              [Drama, War]
# 2 Fast 2 Furious                     [Action, Crime, Thriller]
# 2012                               [Action, Adventure, Sci-Fi]

# %% [markdown]
# #### Additional cleaning is required to convert all the dollar amounts and the release months and years to numerical values.

# %%
top1000['worldwide_gross'] = top1000['worldwide_gross'].str.replace("$","").str.replace(",","")
top1000['domestic_gross'] = top1000['domestic_gross'].str.replace("$","").str.replace(",","")

# %%
top1000['worldwide_gross'] = pd.to_numeric(top1000['worldwide_gross'])
top1000['domestic_gross'] = pd.to_numeric(top1000['domestic_gross'])
top1000['year'] = pd.to_numeric(top1000['year'])
top1000['budget'] = pd.to_numeric(top1000['budget'])

months = {'January':1, 'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}
top1000.release_month = top1000.release_month.map(months)

# %%
top1000.sort_values('worldwide_gross', ascending=False, inplace=True)
top1000.head()
# Out:
#                                                 url_slug  worldwide_gross  \
# Avengers: Endgame  /title/tt4154796/?ref_=bo_cso_table_1       2797800564
# Avatar             /title/tt0499549/?ref_=bo_cso_table_2       2790439092
# Titanic            /title/tt0120338/?ref_=bo_cso_table_3       2195169869
# Jurassic World     /title/tt0369610/?ref_=bo_cso_table_6       1670401444
# The Avengers       /title/tt0848228/?ref_=bo_cso_table_8       1518815515
#
#                    domestic_gross  year                          distributor  \
# Avengers: Endgame       858373000  2019  Walt Disney Studios Motion Pictures
# Avatar                  760507625  2009                Twentieth Century Fox
# Titanic                 659363944  1997                   Paramount Pictures
# Jurassic World          652270625  2015                   Universal Pictures
# The Avengers            623357910  2012  Walt Disney Studios Motion Pictures
#
#                       budget  release_month rating  runtime  \
# Avengers: Endgame  356000000              4  PG-13      181
# Avatar             237000000             12  PG-13      162
# Titanic            200000000             12  PG-13      194
# Jurassic World     150000000              6  PG-13      124
# The Avengers       220000000              4  PG-13      143
#
#                                                   genre
# Avengers: Endgame    [Action, Adventure, Drama, Sci-Fi]
# Avatar             [Action, Adventure, Fantasy, Sci-Fi]
# Titanic                                [Drama, Romance]
# Jurassic World              [Action, Adventure, Sci-Fi]
# The Avengers                [Action, Adventure, Sci-Fi]

# %% [markdown]
# #### I save it to pickle to use in another notebook for my regression analysis.

# %%
import pickle

# %%
top1000.to_pickle('top1000.pkl')
